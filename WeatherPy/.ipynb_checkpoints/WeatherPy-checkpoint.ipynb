# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 631

# %%
#url= "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key
#url

url="http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# %%
#city_url = url + "&q=" + city
#city_url
city_url = f"{url}appid={weather_api_key}&units={units}&q="+city
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=45310f5ed7707d634e1fc04a617b885e&units=metric&q=upernavik'

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL

#url="http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

url="http://api.openweathermap.org/data/2.5/weather?"
units = "metric"    

# Define an empty list to fetch the weather data for each city
city_data = []
lat = []
temp_max = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city


    city_url = f"{url}appid={weather_api_key}&units={units}&q="+city
    
    #city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities

    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url)
        city_weather=city_weather.json()


        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind =city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        


        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    
   #except:
    #    print("City not found. Skipping...")
     #   pass
              
    except Exception as e:
        import traceback
        print(traceback.format_exc())
        
        
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aksu
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | mys shmidta
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 4 of Set 1 | vagur
# Processing Record 5 of Set 1 | orbetello
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | barentu
# Processing Record 9 of Set 1 | palabuhanratu
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | port hardy
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | port blair
# Processing Record 14 of Set 1 | lata
# Processing Record 15 of Set 1 | valle hermoso
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | balikpapan
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bahia blanca
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | half moon bay
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | tombouctou
# Processing Record 25 of Set 1 | adrar
# Processing Record 26 of Set 1 | andahuaylas
# Processing Record 27 of Set 1 | yining
# Processing Record 28 of Set 1 | grand river south east
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 29 of Set 1 | sao filipe
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | lakselv
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | grinnell
# Processing Record 39 of Set 1 | rovaniemi
# Processing Record 40 of Set 1 | faanui
# Processing Record 41 of Set 1 | cedar rapids
# Processing Record 42 of Set 1 | port lincoln
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | castlegar
# Processing Record 45 of Set 1 | carlsbad
# Processing Record 46 of Set 1 | rawannawi
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 47 of Set 1 | saskylakh
# Processing Record 48 of Set 1 | vostochnyy
# Processing Record 49 of Set 1 | aden
# Processing Record 50 of Set 1 | eseka
# Processing Record 0 of Set 2 | margate
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | bandarbeyla
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | geraldton
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | srednekolymsk
# Processing Record 10 of Set 2 | wanning
# Processing Record 11 of Set 2 | rio grande
# Processing Record 12 of Set 2 | ambon
# Processing Record 13 of Set 2 | yulara
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | sarangani
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | meyungs
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 18 of Set 2 | killybegs
# Processing Record 19 of Set 2 | ternate
# Processing Record 20 of Set 2 | maglie
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | hay river
# Processing Record 24 of Set 2 | husavik
# Processing Record 25 of Set 2 | blagoyevo
# Processing Record 26 of Set 2 | la ronge
# Processing Record 27 of Set 2 | bengkulu
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | gat
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | saint-augustin
# Processing Record 33 of Set 2 | pandan
# Processing Record 34 of Set 2 | fortuna
# Processing Record 35 of Set 2 | naro moru
# Processing Record 36 of Set 2 | coquimbo
# Processing Record 37 of Set 2 | kodiak
# Processing Record 38 of Set 2 | saleaula
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 39 of Set 2 | acapulco
# Processing Record 40 of Set 2 | belushya guba
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 41 of Set 2 | grindavik
# Processing Record 42 of Set 2 | temaraia
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 43 of Set 2 | guajara-mirim
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 44 of Set 2 | puerto quijarro
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | komsomolskiy
# Processing Record 47 of Set 2 | coihaique
# Processing Record 48 of Set 2 | parabel
# Processing Record 49 of Set 2 | yerbogachen
# Processing Record 0 of Set 3 | dianopolis
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 1 of Set 3 | mayenne
# Processing Record 2 of Set 3 | palmer
# Processing Record 3 of Set 3 | laguna
# Processing Record 4 of Set 3 | bosaso
# Processing Record 5 of Set 3 | arraial do cabo
# Processing Record 6 of Set 3 | vaitupu
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 7 of Set 3 | attawapiskat
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 8 of Set 3 | busselton
# Processing Record 9 of Set 3 | mill valley
# Processing Record 10 of Set 3 | abha
# Processing Record 11 of Set 3 | jiuquan
# Processing Record 12 of Set 3 | avera
# Processing Record 13 of Set 3 | san jorge
# Processing Record 14 of Set 3 | buala
# Processing Record 15 of Set 3 | mahibadhoo
# Processing Record 16 of Set 3 | illoqqortoormiut
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 17 of Set 3 | dekoa
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 18 of Set 3 | bud
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | kidal
# Processing Record 21 of Set 3 | jieshi
# Processing Record 22 of Set 3 | tuktoyaktuk
# Processing Record 23 of Set 3 | baykit
# Processing Record 24 of Set 3 | carnarvon
# Processing Record 25 of Set 3 | ryotsu
# Processing Record 26 of Set 3 | kokopo
# Processing Record 27 of Set 3 | shimoda
# Processing Record 28 of Set 3 | namibe
# Processing Record 29 of Set 3 | zhanatas
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 30 of Set 3 | port alfred
# Processing Record 31 of Set 3 | kitimat
# Processing Record 32 of Set 3 | zomin
# Processing Record 33 of Set 3 | codrington
# Processing Record 34 of Set 3 | tuatapere
# Processing Record 35 of Set 3 | torbay
# Processing Record 36 of Set 3 | road town
# Processing Record 37 of Set 3 | sechura
# Processing Record 38 of Set 3 | ilulissat
# Processing Record 39 of Set 3 | dikson
# Processing Record 40 of Set 3 | sentyabrskiy
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 41 of Set 3 | narsaq
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | haines junction
# Processing Record 44 of Set 3 | penzance
# Processing Record 45 of Set 3 | gariaband
# Processing Record 46 of Set 3 | georgetown
# Processing Record 47 of Set 3 | nguiu
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 48 of Set 3 | malmesbury
# Processing Record 49 of Set 3 | galle
# Processing Record 0 of Set 4 | san policarpo
# Processing Record 1 of Set 4 | mecca
# Processing Record 2 of Set 4 | chuy
# Processing Record 3 of Set 4 | cayenne
# Processing Record 4 of Set 4 | kenai
# Processing Record 5 of Set 4 | sola
# Processing Record 6 of Set 4 | pasighat
# Processing Record 7 of Set 4 | kovylkino
# Processing Record 8 of Set 4 | nizwa
# Processing Record 9 of Set 4 | asfi
# Processing Record 10 of Set 4 | puerto ayora
# Processing Record 11 of Set 4 | nargana
# Processing Record 12 of Set 4 | vardo
# Processing Record 13 of Set 4 | mukhen
# Processing Record 14 of Set 4 | vanderhoof
# Processing Record 15 of Set 4 | cidreira
# Processing Record 16 of Set 4 | port hedland
# Processing Record 17 of Set 4 | norman wells
# Processing Record 18 of Set 4 | vao
# Processing Record 19 of Set 4 | souillac
# Processing Record 20 of Set 4 | pathein
# Processing Record 21 of Set 4 | saint-francois
# Processing Record 22 of Set 4 | sawakin
# Processing Record 23 of Set 4 | ust-nera
# Processing Record 24 of Set 4 | khatanga
# Processing Record 25 of Set 4 | makungu
# Processing Record 26 of Set 4 | khandagayty
# Processing Record 27 of Set 4 | chernyshevskiy
# Processing Record 28 of Set 4 | san jose
# Processing Record 29 of Set 4 | salalah
# Processing Record 30 of Set 4 | porto santo
# Processing Record 31 of Set 4 | taolanaro
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 32 of Set 4 | lilongwe
# Processing Record 33 of Set 4 | dicabisagan
# Processing Record 34 of Set 4 | port keats
# Processing Record 35 of Set 4 | pinega
# Processing Record 36 of Set 4 | yumen
# Processing Record 37 of Set 4 | grants
# Processing Record 38 of Set 4 | nemuro
# Processing Record 39 of Set 4 | leningradskiy
# Processing Record 40 of Set 4 | kavieng
# Processing Record 41 of Set 4 | kuche
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 42 of Set 4 | serowe
# Processing Record 43 of Set 4 | labuhan
# Processing Record 44 of Set 4 | vaini
# Processing Record 45 of Set 4 | vikulovo
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | mananjary
# Processing Record 48 of Set 4 | fonte boa
# Processing Record 49 of Set 4 | christchurch
# Processing Record 0 of Set 5 | berlevag
# Processing Record 1 of Set 5 | snezhnogorsk
# Processing Record 2 of Set 5 | ambilobe
# Processing Record 3 of Set 5 | victoria
# Processing Record 4 of Set 5 | rzhev
# Processing Record 5 of Set 5 | talaya
# Processing Record 6 of Set 5 | kamaishi
# Processing Record 7 of Set 5 | san patricio
# Processing Record 8 of Set 5 | santa fe
# Processing Record 9 of Set 5 | villazon
# Processing Record 10 of Set 5 | bargal
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 11 of Set 5 | verkhneyarkeyevo
# Processing Record 12 of Set 5 | tera
# Processing Record 13 of Set 5 | marcona
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 14 of Set 5 | san felipe
# Processing Record 15 of Set 5 | ancud
# Processing Record 16 of Set 5 | ha tinh
# Processing Record 17 of Set 5 | port augusta
# Processing Record 18 of Set 5 | halalo
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 19 of Set 5 | ketchikan
# Processing Record 20 of Set 5 | naze
# Processing Record 21 of Set 5 | saint george
# Processing Record 22 of Set 5 | longyearbyen
# Processing Record 23 of Set 5 | dubuque
# Processing Record 24 of Set 5 | coahuayana
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | tessalit
# Processing Record 27 of Set 5 | sumbe
# Processing Record 28 of Set 5 | terrace
# Processing Record 29 of Set 5 | mount isa
# Processing Record 30 of Set 5 | umm lajj
# Processing Record 31 of Set 5 | oistins
# Processing Record 32 of Set 5 | tocache
# Processing Record 33 of Set 5 | dhidhdhoo
# Processing Record 34 of Set 5 | kangaatsiaq
# Processing Record 35 of Set 5 | siyabuswa
# Processing Record 36 of Set 5 | mount pleasant
# Processing Record 37 of Set 5 | santa isabel do rio negro
# Processing Record 38 of Set 5 | airai
# Processing Record 39 of Set 5 | grand gaube
# Processing Record 40 of Set 5 | thompson
# Processing Record 41 of Set 5 | cherskiy
# Processing Record 42 of Set 5 | vazante
# Processing Record 43 of Set 5 | dien bien
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 44 of Set 5 | jiayuguan
# Processing Record 45 of Set 5 | ahipara
# Processing Record 46 of Set 5 | sibu
# Processing Record 47 of Set 5 | santa maria da vitoria
# Processing Record 48 of Set 5 | seymchan
# Processing Record 49 of Set 5 | morrelganj
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 0 of Set 6 | kambove
# Processing Record 1 of Set 6 | sembe
# Processing Record 2 of Set 6 | pecos
# Processing Record 3 of Set 6 | nishihara
# Processing Record 4 of Set 6 | westport
# Processing Record 5 of Set 6 | singaraja
# Processing Record 6 of Set 6 | nanortalik
# Processing Record 7 of Set 6 | tigil
# Processing Record 8 of Set 6 | vallenar
# Processing Record 9 of Set 6 | toungoo
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 10 of Set 6 | hendijan
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 11 of Set 6 | kununurra
# Processing Record 12 of Set 6 | ngunguru
# Processing Record 13 of Set 6 | nuevo progreso
# Processing Record 14 of Set 6 | pisco
# Processing Record 15 of Set 6 | truro
# Processing Record 16 of Set 6 | omboue
# Processing Record 17 of Set 6 | porto empedocle
# Processing Record 18 of Set 6 | brae
# Processing Record 19 of Set 6 | bilibino
# Processing Record 20 of Set 6 | marsh harbour
# Processing Record 21 of Set 6 | kaili
# Processing Record 22 of Set 6 | rawson
# Processing Record 23 of Set 6 | biak
# Processing Record 24 of Set 6 | lavrentiya
# Processing Record 25 of Set 6 | wokha
# Processing Record 26 of Set 6 | pimentel
# Processing Record 27 of Set 6 | padang
# Processing Record 28 of Set 6 | raton
# Processing Record 29 of Set 6 | ca mau
# Processing Record 30 of Set 6 | barrow
# Processing Record 31 of Set 6 | abbeville
# Processing Record 32 of Set 6 | shenjiamen
# Processing Record 33 of Set 6 | tambura
# Processing Record 34 of Set 6 | ostrovnoy
# Processing Record 35 of Set 6 | east london
# Processing Record 36 of Set 6 | gornopravdinsk
# Processing Record 37 of Set 6 | vandoeuvre-les-nancy
# Processing Record 38 of Set 6 | galveston
# Processing Record 39 of Set 6 | san quintin
# Processing Record 40 of Set 6 | mahebourg
# Processing Record 41 of Set 6 | cubuk
# Processing Record 42 of Set 6 | hofn
# Processing Record 43 of Set 6 | karasburg
# Processing Record 44 of Set 6 | henties bay
# Processing Record 45 of Set 6 | witney
# Processing Record 46 of Set 6 | amapa
# Processing Record 47 of Set 6 | hervey bay
# Processing Record 48 of Set 6 | upata
# Processing Record 49 of Set 6 | hobyo
# Processing Record 0 of Set 7 | alice springs
# Processing Record 1 of Set 7 | kobyzhcha
# Processing Record 2 of Set 7 | le port
# Processing Record 3 of Set 7 | udachnyy
# Processing Record 4 of Set 7 | kaitangata
# Processing Record 5 of Set 7 | tezu
# Processing Record 6 of Set 7 | asau
# Processing Record 7 of Set 7 | sabang
# Processing Record 8 of Set 7 | isangel
# Processing Record 9 of Set 7 | borama
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 10 of Set 7 | inhambane
# Processing Record 11 of Set 7 | morro bay
# Processing Record 12 of Set 7 | poum
# Processing Record 13 of Set 7 | thilogne
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 14 of Set 7 | walvis bay
# Processing Record 15 of Set 7 | hvide sande
# Processing Record 16 of Set 7 | nabire
# Processing Record 17 of Set 7 | ati
# Processing Record 18 of Set 7 | talnakh
# Processing Record 19 of Set 7 | libourne
# Processing Record 20 of Set 7 | praia
# Processing Record 21 of Set 7 | haverfordwest
# Processing Record 22 of Set 7 | mount gambier
# Processing Record 23 of Set 7 | bima
# Processing Record 24 of Set 7 | port macquarie
# Processing Record 25 of Set 7 | lagoa
# Processing Record 26 of Set 7 | broome
# Processing Record 27 of Set 7 | champerico
# Processing Record 28 of Set 7 | truth or consequences
# Processing Record 29 of Set 7 | guerrero negro
# Processing Record 30 of Set 7 | tarbes
# Processing Record 31 of Set 7 | grenaa
# Processing Record 32 of Set 7 | qaanaaq
# Processing Record 33 of Set 7 | roseburg
# Processing Record 34 of Set 7 | calvinia
# Processing Record 35 of Set 7 | miles city
# Processing Record 36 of Set 7 | axim
# Processing Record 37 of Set 7 | mamallapuram
# Processing Record 38 of Set 7 | ciudad bolivar
# Processing Record 39 of Set 7 | capim grosso
# Processing Record 40 of Set 7 | shitkino
# Processing Record 41 of Set 7 | bambous virieux
# Processing Record 42 of Set 7 | otuzco
# Processing Record 43 of Set 7 | clyde river
# Processing Record 44 of Set 7 | ust-ilimsk
# Processing Record 45 of Set 7 | capreol
# Processing Record 46 of Set 7 | najran
# Processing Record 47 of Set 7 | abdulino
# Processing Record 48 of Set 7 | agadez
# Processing Record 49 of Set 7 | jacareacanga
# Processing Record 0 of Set 8 | chiang klang
# Processing Record 1 of Set 8 | ankang
# Processing Record 2 of Set 8 | manohar thana
# Processing Record 3 of Set 8 | katsuura
# Processing Record 4 of Set 8 | atka
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 5 of Set 8 | gudari
# Processing Record 6 of Set 8 | puerto narino
# Processing Record 7 of Set 8 | lompoc
# Processing Record 8 of Set 8 | tabuk
# Processing Record 9 of Set 8 | kamenskoye
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 10 of Set 8 | azul
# Processing Record 11 of Set 8 | vostok
# Processing Record 12 of Set 8 | sitka
# Processing Record 13 of Set 8 | batagay-alyta
# Processing Record 14 of Set 8 | esmeraldas
# Processing Record 15 of Set 8 | gravelbourg
# Processing Record 16 of Set 8 | pacific grove
# Processing Record 17 of Set 8 | riyadh
# Processing Record 18 of Set 8 | miyako
# Processing Record 19 of Set 8 | huarmey
# Processing Record 20 of Set 8 | general roca
# Processing Record 21 of Set 8 | huancavelica
# Processing Record 22 of Set 8 | salinas
# Processing Record 23 of Set 8 | hauterive
# Processing Record 24 of Set 8 | zinder
# Processing Record 25 of Set 8 | tiarei
# Processing Record 26 of Set 8 | traverse city
# Processing Record 27 of Set 8 | tokur
# Processing Record 28 of Set 8 | zhovtneve
# Processing Record 29 of Set 8 | eyl
# Processing Record 30 of Set 8 | linxia
# Processing Record 31 of Set 8 | namie
# Processing Record 32 of Set 8 | constitucion
# Processing Record 33 of Set 8 | bafra
# Processing Record 34 of Set 8 | callaway
# Processing Record 35 of Set 8 | mocuba
# Processing Record 36 of Set 8 | kerrville
# Processing Record 37 of Set 8 | bolshiye uki
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 38 of Set 8 | sofiysk
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 39 of Set 8 | arlit
# Processing Record 40 of Set 8 | eydhafushi
# Processing Record 41 of Set 8 | bria
# Processing Record 42 of Set 8 | warqla
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 43 of Set 8 | vila franca do campo
# Processing Record 44 of Set 8 | gol
# Processing Record 45 of Set 8 | ust-kuyga
# Processing Record 46 of Set 8 | xilagani
# Processing Record 47 of Set 8 | tarime
# Processing Record 48 of Set 8 | zaraza
# Processing Record 49 of Set 8 | baker city
# Processing Record 0 of Set 9 | pechenga
# Processing Record 1 of Set 9 | constantine
# Processing Record 2 of Set 9 | ginda
# Processing Record 3 of Set 9 | pahrump
# Processing Record 4 of Set 9 | moron
# Processing Record 5 of Set 9 | beloha
# Processing Record 6 of Set 9 | akonolinga
# Processing Record 7 of Set 9 | mabaruma
# Processing Record 8 of Set 9 | jiazi
# Processing Record 9 of Set 9 | santa rosa
# Processing Record 10 of Set 9 | aligudarz
# Processing Record 11 of Set 9 | chardara
# Processing Record 12 of Set 9 | hun
# Processing Record 13 of Set 9 | ajaccio
# Processing Record 14 of Set 9 | belle fourche
# Processing Record 15 of Set 9 | phalombe
# Processing Record 16 of Set 9 | hirado
# Processing Record 17 of Set 9 | hasaki
# Processing Record 18 of Set 9 | namatanai
# Processing Record 19 of Set 9 | maceio
# Processing Record 20 of Set 9 | bereda
# Processing Record 21 of Set 9 | pangai
# Processing Record 22 of Set 9 | matagami
# Processing Record 23 of Set 9 | general cepeda
# Processing Record 24 of Set 9 | ola
# Processing Record 25 of Set 9 | muravlenko
# Processing Record 26 of Set 9 | turukhansk
# Processing Record 27 of Set 9 | los llanos de aridane
# Processing Record 28 of Set 9 | harper
# Processing Record 29 of Set 9 | kirakira
# Processing Record 30 of Set 9 | meulaboh
# Processing Record 31 of Set 9 | avigliano
# Processing Record 32 of Set 9 | kiunga
# Processing Record 33 of Set 9 | kahului
# Processing Record 34 of Set 9 | wamba
# Processing Record 35 of Set 9 | agirish
# Processing Record 36 of Set 9 | murgab
# Processing Record 37 of Set 9 | bathsheba
# Processing Record 38 of Set 9 | sao felix do xingu
# Processing Record 39 of Set 9 | clonakilty
# Processing Record 40 of Set 9 | requena
# Processing Record 41 of Set 9 | neiafu
# Processing Record 42 of Set 9 | alyangula
# Processing Record 43 of Set 9 | sabha
# Processing Record 44 of Set 9 | ardesen
# Processing Record 45 of Set 9 | raudeberg
# Processing Record 46 of Set 9 | camabatela
# Processing Record 47 of Set 9 | irtyshskiy
# Processing Record 48 of Set 9 | ovsyanka
# Processing Record 49 of Set 9 | maues
# Processing Record 0 of Set 10 | verkhoyansk
# Processing Record 1 of Set 10 | kalmunai
# Processing Record 2 of Set 10 | nianzishan
# Processing Record 3 of Set 10 | blonduos
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 4 of Set 10 | izmir
# Processing Record 5 of Set 10 | fernie
# Processing Record 6 of Set 10 | amderma
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 7 of Set 10 | ambato
# Processing Record 8 of Set 10 | preobrazheniye
# Processing Record 9 of Set 10 | mahon
# Processing Record 10 of Set 10 | balgazyn
# Processing Record 11 of Set 10 | pangnirtung
# Processing Record 12 of Set 10 | bubaque
# Processing Record 13 of Set 10 | tanete
# Processing Record 14 of Set 10 | tabiauea
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 15 of Set 10 | kafue
# Processing Record 16 of Set 10 | avanigadda
# Processing Record 17 of Set 10 | goderich
# Processing Record 18 of Set 10 | college
# Processing Record 19 of Set 10 | moosburg
# Processing Record 20 of Set 10 | sao bento
# Processing Record 21 of Set 10 | utete
# Processing Record 22 of Set 10 | klaksvik
# Processing Record 23 of Set 10 | pevek
# Processing Record 24 of Set 10 | wagar
# Processing Record 25 of Set 10 | leua
# Processing Record 26 of Set 10 | flin flon
# Processing Record 27 of Set 10 | dire
# Processing Record 28 of Set 10 | hami
# Processing Record 29 of Set 10 | rungata
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 30 of Set 10 | marrakesh
# Processing Record 31 of Set 10 | port hawkesbury
# Processing Record 32 of Set 10 | ranong
# Processing Record 33 of Set 10 | kyshtovka
# Processing Record 34 of Set 10 | ternovka
# Processing Record 35 of Set 10 | saldanha
# Processing Record 36 of Set 10 | urumqi
# Processing Record 37 of Set 10 | ayna
# Processing Record 38 of Set 10 | aykhal
# Processing Record 39 of Set 10 | torres
# Processing Record 40 of Set 10 | yorkton
# Processing Record 41 of Set 10 | roma
# Processing Record 42 of Set 10 | smolenka
# Processing Record 43 of Set 10 | lima
# Processing Record 44 of Set 10 | caravelas
# Processing Record 45 of Set 10 | alotau
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 46 of Set 10 | rulenge
# Processing Record 47 of Set 10 | primorsko-akhtarsk
# Processing Record 48 of Set 10 | bontang
# Processing Record 49 of Set 10 | ust-uda
# Processing Record 0 of Set 11 | onguday
# Processing Record 1 of Set 11 | alofi
# Processing Record 2 of Set 11 | luderitz
# Processing Record 3 of Set 11 | ygatimi
# Processing Record 4 of Set 11 | egvekinot
# Processing Record 5 of Set 11 | ergani
# Processing Record 6 of Set 11 | kavaratti
# Processing Record 7 of Set 11 | nizhneyansk
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 8 of Set 11 | salisbury
# Processing Record 9 of Set 11 | pak phanang
# Processing Record 10 of Set 11 | skiros
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 11 of Set 11 | berdyuzhye
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 12 of Set 11 | gilgit
# Processing Record 13 of Set 11 | presidencia roque saenz pena
# Processing Record 14 of Set 11 | mani
# Processing Record 15 of Set 11 | arman
# Processing Record 16 of Set 11 | iskateley
# Processing Record 17 of Set 11 | dwarka
# Processing Record 18 of Set 11 | faya
# Processing Record 19 of Set 11 | galiwinku
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 20 of Set 11 | esso
# Processing Record 21 of Set 11 | paradwip
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 22 of Set 11 | hualmay
# Processing Record 23 of Set 11 | strzelin
# Processing Record 24 of Set 11 | kulevcha
# Processing Record 25 of Set 11 | atar
# Processing Record 26 of Set 11 | mulege
# Processing Record 27 of Set 11 | puerto escondido
# Processing Record 28 of Set 11 | paita
# Processing Record 29 of Set 11 | andapa
# Processing Record 30 of Set 11 | barentsburg
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 31 of Set 11 | storforshei
# Processing Record 32 of Set 11 | anderson
# Processing Record 33 of Set 11 | goba
# Processing Record 34 of Set 11 | kungurtug
# Processing Record 35 of Set 11 | kabinda
# Processing Record 36 of Set 11 | karabulak
# Processing Record 37 of Set 11 | chokurdakh
# Processing Record 38 of Set 11 | necochea
# Processing Record 39 of Set 11 | tarauaca
# Processing Record 40 of Set 11 | kattivakkam
# Processing Record 41 of Set 11 | esna
# Processing Record 42 of Set 11 | kandrian
# Processing Record 43 of Set 11 | mnogovershinnyy
# Processing Record 44 of Set 11 | motema
# Processing Record 45 of Set 11 | binga
# Processing Record 46 of Set 11 | achisay
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 47 of Set 11 | vero beach
# Processing Record 48 of Set 11 | mahendranagar
# Processing Record 49 of Set 11 | denpasar
# Processing Record 0 of Set 12 | progreso
# Processing Record 1 of Set 12 | celestun
# Processing Record 2 of Set 12 | farafangana
# Processing Record 3 of Set 12 | fujin
# Processing Record 4 of Set 12 | gimli
# Processing Record 5 of Set 12 | santa luzia
# Processing Record 6 of Set 12 | havre-saint-pierre
# Processing Record 7 of Set 12 | fort morgan
# Processing Record 8 of Set 12 | kocevje
# Processing Record 9 of Set 12 | fort saint james
# Processing Record 10 of Set 12 | tilichiki
# Processing Record 11 of Set 12 | olavarria
# Processing Record 12 of Set 12 | gunnedah
# Processing Record 13 of Set 12 | dondaicha
# Processing Record 14 of Set 12 | tidore
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 15 of Set 12 | noumea
# Processing Record 16 of Set 12 | sawtell
# Processing Record 17 of Set 12 | privokzalnyy
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 18 of Set 12 | tomatlan
# Processing Record 19 of Set 12 | bairiki
# Processing Record 20 of Set 12 | manica
# Processing Record 21 of Set 12 | nanakuli
# Processing Record 22 of Set 12 | muros
# Processing Record 23 of Set 12 | samarai
# Processing Record 24 of Set 12 | delijan
# Processing Record 25 of Set 12 | tarko-sale
# Processing Record 26 of Set 12 | kilemary
# Processing Record 27 of Set 12 | sulzbach-rosenberg
# Processing Record 28 of Set 12 | soyo
# Processing Record 29 of Set 12 | casper
# Processing Record 30 of Set 12 | molina
# Processing Record 31 of Set 12 | mandalgovi
# Processing Record 32 of Set 12 | burica
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 33 of Set 12 | barra dos coqueiros
# Processing Record 34 of Set 12 | waiuku
# Processing Record 35 of Set 12 | hamilton
# Processing Record 36 of Set 12 | sonqor
# Processing Record 37 of Set 12 | san cristobal
# Processing Record 38 of Set 12 | leopold
# Processing Record 39 of Set 12 | prince rupert
# Processing Record 40 of Set 12 | sindon
# Processing Record 41 of Set 12 | gomel
# Processing Record 42 of Set 12 | el alto
# Processing Record 43 of Set 12 | naron
# Processing Record 44 of Set 12 | mercedes
# Processing Record 45 of Set 12 | ye
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 46 of Set 12 | vaitape
# Processing Record 47 of Set 12 | rena
# Processing Record 48 of Set 12 | melfort
# Processing Record 49 of Set 12 | beckley
# Processing Record 0 of Set 13 | ozark
# Processing Record 1 of Set 13 | diffa
# Processing Record 2 of Set 13 | fairbanks
# Processing Record 3 of Set 13 | dharchula
# Processing Record 4 of Set 13 | osypenko
# Processing Record 5 of Set 13 | dunedin
# Processing Record 6 of Set 13 | touros
# Processing Record 7 of Set 13 | tautira
# Processing Record 8 of Set 13 | aktash
# Processing Record 9 of Set 13 | camopi
# Processing Record 10 of Set 13 | dalbandin
# Processing Record 11 of Set 13 | bac lieu
# Processing Record 12 of Set 13 | oksfjord
# Processing Record 13 of Set 13 | kaduna
# Processing Record 14 of Set 13 | ilinskiy
# Processing Record 15 of Set 13 | dasoguz
# Processing Record 16 of Set 13 | mapiri
# Processing Record 17 of Set 13 | esperance
# Processing Record 18 of Set 13 | kruisfontein
# Processing Record 19 of Set 13 | dryden
# Processing Record 20 of Set 13 | bjornevatn
# Processing Record 21 of Set 13 | stains
# Processing Record 22 of Set 13 | eureka
# Processing Record 23 of Set 13 | amahai
# Processing Record 24 of Set 13 | keflavik
# Processing Record 25 of Set 13 | safaqis
# Traceback (most recent call last):
#   File "C:\Users\MarcelaTerán\AppData\Local\Temp\ipykernel_22196\3908873995.py", line 52, in <module>
#     city_lat = city_weather["coord"]["lat"]
# KeyError: 'coord'
#
# Processing Record 26 of Set 13 | waddan
# Processing Record 27 of Set 13 | paamiut
# Processing Record 28 of Set 13 | taoudenni
# Processing Record 29 of Set 13 | cascais
# Processing Record 30 of Set 13 | haifa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

city_data_df

# Show Record Count
city_data_df.count()
# Out:
# City          581
# lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       aksu  41.1231  80.2644      7.32        39          55        1.21
# 1    iqaluit  63.7506 -68.5145    -13.15        84         100        1.54
# 2      vagur  61.4732  -6.8119      6.94        81         100        6.15
# 3  orbetello  42.4408  11.2196      8.99        92         100        3.84
# 4  hithadhoo  -0.6000  73.0833     27.08        76          96        2.43
#
#   Country        Date
# 0      CN  1677816398
# 1      CA  1677816399
# 2      FO  1677816400
# 3      IT  1677816400
# 4      MV  1677816401

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             aksu  41.1231  80.2644      7.32        39          55
# 1          iqaluit  63.7506 -68.5145    -13.15        84         100
# 2            vagur  61.4732  -6.8119      6.94        81         100
# 3        orbetello  42.4408  11.2196      8.99        92         100
# 4        hithadhoo  -0.6000  73.0833     27.08        76          96
#
#          Wind Speed Country        Date
# City_ID
# 0              1.21      CN  1677816398
# 1              1.54      CA  1677816399
# 2              6.15      FO  1677816400
# 3              3.84      IT  1677816400
# 4              2.43      MV  1677816401

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

x_values = city_data_df['lat']
y_values = city_data_df['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title("City Max Latitude vs temperature (2022-10-18)")


# Incorporate the other graph properties
plt.scatter(x_values,y_values, c="blue", edgecolor="black",marker="o")
plt.grid(True)
plt.show()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['lat']
y_values = city_data_df['Humidity']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title("City Latitude vs Humidity (2022-10-18)")
plt.scatter(x_values,y_values, c="purple", edgecolor="black",marker="o")
plt.grid(True)
plt.show()


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['lat']
y_values = city_data_df['Cloudiness']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title("City Latitude vs Cloudiness (2022-10-18)")
plt.scatter(x_values,y_values, c="lightblue", edgecolor="black",marker="o")
plt.grid(True)
plt.show()


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['lat']
y_values = city_data_df['Wind Speed']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s))')
plt.title("City Latitude vs Wind Speed (2022-10-18)")
#plt.grid(True)


# Incorporate the other graph properties
plt.scatter(x_values,y_values, c="pink", edgecolor="black",marker="o")
plt.grid(True)
plt.show()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
print(regress_values)
# Out:
# City_ID
# 0      3.443245
# 1      3.418119
# 2      3.420648
# 3      3.441782
# 4      3.489575
#          ...
# 576    3.456528
# 577    3.420070
# 578    3.463727
# 579    3.445938
# 580    3.452470
# Name: lat, Length: 581, dtype: float64

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)

northern_hemi_df=city_data_df.loc[(city_data_df["lat"] >=0)]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             aksu  41.1231  80.2644      7.32        39          55
# 1          iqaluit  63.7506 -68.5145    -13.15        84         100
# 2            vagur  61.4732  -6.8119      6.94        81         100
# 3        orbetello  42.4408  11.2196      8.99        92         100
# 6          barentu  15.1139  37.5928     21.21        57          47
#
#          Wind Speed Country        Date
# City_ID
# 0              1.21      CN  1677816398
# 1              1.54      CA  1677816399
# 2              6.15      FO  1677816400
# 3              3.84      IT  1677816400
# 6              1.63      ER  1677816402

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
#southern_hemi = []

southern_hemi_df=city_data_df.loc[(city_data_df["lat"] <0)]

              
# Display sample data
southern_hemi_df.head()
# Out:
#                  City      lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4           hithadhoo  -0.6000   73.0833     27.08        76          96
# 5            hermanus -34.4187   19.2345     19.51        81           0
# 14             avarua -21.2078 -159.7750     29.03        61          20
# 15         balikpapan  -1.2675  116.8289     26.55        83          40
# 16       punta arenas -53.1500  -70.9167      4.06        81          40
#
#          Wind Speed Country        Date
# City_ID
# 4              2.43      MV  1677816401
# 5              4.20      ZA  1677816401
# 14             2.57      CK  1677816407
# 15             0.51      ID  1677816330
# 16             8.23      CL  1677816143

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values=northern_hemi_df['lat']
y_values=northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
regress_values = x_values * slope + intercept
#print(regress_values)

#print(line_eq)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.7874433329634044

# %%
# Linear regression on Southern Hemisphere
x_values=southern_hemi_df['lat']
y_values=southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

regress_values = x_values * slope + intercept
#print(regress_values)

#print(line_eq)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(-45,5),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.14x +25.55
# The r-value is: 0.10217709659878993

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x_values=northern_hemi_df['lat']
y_values=northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
regress_values = x_values * slope + intercept
#print(regress_values)

#print(line_eq)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(50,20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.17088561954948453

# %%
# Southern Hemisphere
x_values=southern_hemi_df['lat']
y_values=southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

regress_values = x_values * slope + intercept
#print(regress_values)

#print(line_eq)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(-30,25),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 0.43x +86.8
# The r-value is: 0.11580755484148834

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values=northern_hemi_df['lat']
y_values=northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
regress_values = x_values * slope + intercept
#print(regress_values)

#print(line_eq)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(50,20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.06329638467987683

# %%
# Southern Hemisphere
x_values=southern_hemi_df['lat']
y_values=southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

regress_values = x_values * slope + intercept
#print(regress_values)

#print(line_eq)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(-30,25),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = 1.07x +82.42
# The r-value is: 0.12799887964099213

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values=northern_hemi_df['lat']
y_values=northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
regress_values = x_values * slope + intercept
#print(regress_values)

#print(line_eq)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,12),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# The r-value is: 0.001773264071573038

# %%
# Southern Hemisphere
x_values=southern_hemi_df['lat']
y_values=southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

regress_values = x_values * slope + intercept
#print(regress_values)

#print(line_eq)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(-40,12),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

plt.show()
# Out:
# y = -0.05x +2.33
# The r-value is: 0.07928490283302311

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
